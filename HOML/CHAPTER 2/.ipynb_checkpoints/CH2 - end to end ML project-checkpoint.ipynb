# %% [markdown]
# # Getting The Data

# %%
import pandas as pd
import urllib.request

url = "https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv"
urllib.request.urlretrieve(url, "housing_csv")
# Out:
# ('housing_csv', <http.client.HTTPMessage at 0x7fce33d43310>)

# %%
housing = pd.read_csv(url)

# %%
housing.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing.loc[:,"ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# ## initial visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-pastel")
sns.set_theme(color_codes=True)


housing.hist(bins = 50, figsize=(20,15), color="#03aeb4");

# %% [markdown]
# ## train test split

# %%
#completely random sampling
#but we can also have a stratifies sampling

from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
#added a new column of income category for stratified sampling

housing.loc[:, "income_cat"] = pd.cut(housing.loc[:, "median_income"], 
                                     bins = [0,1.5, 3, 4.5, 6, np.inf],
                                     labels = [ 1,2,3,4,5])

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   income_cat
# 0          5
# 1          5
# 2          5
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit

s_split = StratifiedShuffleSplit(n_splits=1, test_size = 0.2, random_state=42)

for train_index, test_index in s_split.split(housing, housing.loc[:,"income_cat"]):
    strat_train_set = housing.loc[train_index] 
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241     -118.39     34.12                29.0       6447.0          1012.0
# 10970    -117.86     33.77                39.0       4159.0           655.0
# 20351    -119.05     34.21                27.0       4357.0           926.0
# 6568     -118.15     34.20                52.0       1786.0           306.0
# 13285    -117.68     34.07                32.0       1775.0           314.0
# ...          ...       ...                 ...          ...             ...
# 20519    -121.53     38.58                33.0       4988.0          1169.0
# 17430    -120.44     34.65                30.0       2265.0           512.0
# 4019     -118.49     34.18                31.0       3073.0           674.0
# 12107    -117.32     33.99                27.0       5464.0           850.0
# 2398     -118.91     36.79                19.0       1616.0           324.0
#
# ...

# %%
strat_test_set.drop("income_cat", axis=1, inplace=True)
strat_train_set.drop("income_cat", axis=1, inplace=True)

# %%
strat_test_set.head(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241     -118.39     34.12                29.0       6447.0          1012.0
# 10970    -117.86     33.77                39.0       4159.0           655.0
#
#        population  households  median_income  median_house_value  \
# 5241       2184.0       960.0         8.2816            500001.0
# 10970      1669.0       651.0         4.6111            240300.0
#
#       ocean_proximity
# 5241        <1H OCEAN
# 10970       <1H OCEAN

# %%
housing.loc[:,"income_cat"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## visualisation pt2

# %%
sns.scatterplot(x="longitude", y="latitude", data=housing, alpha=0.4)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4, s=housing.loc[:,"population"]/100, label="population", figsize=(20,14),
             c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ## correlation

# %%
corr_matrix = housing.corr()

# %%
corr_matrix.loc[:, "median_house_value"].sort_values()
# Out:
# latitude             -0.144160
# longitude            -0.045967
# population           -0.024650
# total_bedrooms        0.049686
# households            0.065843
# housing_median_age    0.105623
# total_rooms           0.134153
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %%
pd.plotting.scatter_matrix(housing, figsize=(20,10), color="#03aeb4");

# %% [markdown]
# # preparation of data for ML algorithm

# %%
housing.loc[:,"rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing.loc[:,"bedrooms_per_room"] = housing["total_bedrooms"]/housing["total_rooms"]
housing.loc[:,"population_per_household"] = housing["population"]/housing["households"]

# %%
corr_matrix = housing.corr()

corr_matrix
# Out:
#                           longitude  latitude  housing_median_age  \
# longitude                  1.000000 -0.924478           -0.105848
# latitude                  -0.924478  1.000000            0.005766
# housing_median_age        -0.105848  0.005766            1.000000
# total_rooms                0.048871 -0.039184           -0.364509
# total_bedrooms             0.076598 -0.072419           -0.325047
# population                 0.108030 -0.115222           -0.298710
# households                 0.063070 -0.077647           -0.306428
# median_income             -0.019583 -0.075205           -0.111360
# rooms_per_household       -0.028345  0.107621           -0.147186
# bedrooms_per_room          0.095603 -0.116884            0.136788
# population_per_household  -0.000410  0.005420            0.015031
#
#                           total_rooms  total_bedrooms  population  households  \
# longitude                    0.048871        0.076598    0.108030    0.063070
# ...

# %%
housing = strat_train_set.drop("median_house_value", axis=1)
housing_labels = strat_train_set.loc[:,"median_house_value"].copy()

# %% [markdown]
# ## data cleaning

# %%
#making use of imputer

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

#only works with numerical attributes

housing_num = housing.drop("ocean_proximity", axis=1)

imputer.fit(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([-118.51  ,   34.26  ,   29.    , 2119.5   ,  433.    , 1164.    ,
#         408.    ,    3.5409])

# %%
housing_num.median().values
# Out:
# array([-118.51  ,   34.26  ,   29.    , 2119.5   ,  433.    , 1164.    ,
#         408.    ,    3.5409])

# %%
X = imputer.transform(housing_num)

# %%
housing_tr = pd.DataFrame(X, columns=housing_num.columns, index=housing_num.index)

# %%
housing_tr
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17606    -121.89     37.29                38.0       1568.0           351.0
# 18632    -121.93     37.05                14.0        679.0           108.0
# 14650    -117.20     32.77                31.0       1952.0           471.0
# 3230     -119.61     36.31                25.0       1847.0           371.0
# 3555     -118.59     34.23                17.0       6592.0          1525.0
# ...          ...       ...                 ...          ...             ...
# 6563     -118.13     34.20                46.0       1271.0           236.0
# 12053    -117.56     33.88                40.0       1196.0           294.0
# 13908    -116.40     34.09                 9.0       4855.0           872.0
# 11159    -118.01     33.82                31.0       1960.0           380.0
# 15775    -122.45     37.77                52.0       3095.0           682.0
#
#        population  households  median_income
# ...

# %% [markdown]
# ## one hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder
oh = OneHotEncoder()

# %%
housing_cat = housing[["ocean_proximity"]]

# %%
housing_cat.head()
# Out:
#       ocean_proximity
# 17606       <1H OCEAN
# 18632       <1H OCEAN
# 14650      NEAR OCEAN
# 3230           INLAND
# 3555        <1H OCEAN

# %%
housing_cat_1hot = oh.fit_transform(housing_cat)

# %%
housing_cat_1hot
# Out:
# <16512x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16512 stored elements in Compressed Sparse Row format>

# %%
oh.categories_
# Out:
# [array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#        dtype=object)]

# %% [markdown]
# ## pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("std_scaler", StandardScaler())
])

# %%
housing_num_tr = num_pipeline.fit_transform(housing_num)

# %%
housing_num_tr = pd.DataFrame(housing_num_tr, columns=housing_num.columns, index=housing_num.index)

# %%
housing_num_tr.describe().loc["count"]
# Out:
# longitude             16512.0
# latitude              16512.0
# housing_median_age    16512.0
# total_rooms           16512.0
# total_bedrooms        16512.0
# population            16512.0
# households            16512.0
# median_income         16512.0
# Name: count, dtype: float64

# %%
from sklearn.compose import ColumnTransformer

num_att = list(housing_num)
cat_att = ["ocean_proximity"]

full_pipeline = ColumnTransformer([
    ("num", num_pipeline, num_att),
    ("cat", OneHotEncoder(), cat_att)
])

# %%
housing_prepared = full_pipeline.fit_transform(housing)

# %%
#housing_prepared = pd.DataFrame(housing_prepared)

# %%
housing_prepared
# Out:
# array([[-1.15604281,  0.77194962,  0.74333089, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.17602483,  0.6596948 , -1.1653172 , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.18684903, -1.34218285,  0.18664186, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 1.58648943, -0.72478134, -1.56295222, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.78221312, -0.85106801,  0.18664186, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.43579109,  0.99645926,  1.85670895, ...,  0.        ,
#          1.        ,  0.        ]])

# %% [markdown]
# # selecting and training a model

# %% [markdown]
# ## linear regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(housing_prepared, housing_labels)
# Out:
# LinearRegression()

# %%
some_data = housing.iloc[:5]
some_labels = housing_labels.iloc[:5]

# %%
some_data_prepared = full_pipeline.transform(some_data)

# %%
print("prediction :", lin_reg.predict(some_data_prepared))
print("labels :", list(some_labels))
# Out:
# prediction : [211574.39523833 321345.10513719 210947.519838    61921.01197837
#  192362.32961119]
# labels : [286600.0, 340600.0, 196900.0, 46300.0, 254500.0]

# %% [markdown]
# ### error calculation

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = lin_reg.predict(housing_prepared)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)

# %%
lin_rmse
# Out:
# 69050.98178244587

# %% [markdown]
# ## decision tree

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_prepared, housing_labels)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### error calculation

# %%
housing_predictions = tree_reg.predict(housing_prepared)

tree_mse = mean_squared_error(housing_labels, housing_predictions)

tree_rmse = np.sqrt(tree_mse)

tree_rmse
# Out:
# 0.0

# %% [markdown]
# ## cross validation evaluation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(tree_reg, housing_prepared, housing_labels,
                        scoring="neg_mean_squared_error", cv=10)

tree_rmse_cv = np.sqrt(-scores)

# %%
tree_rmse_cv.mean()
# Out:
# 69214.23551482936

# %%
lin_scores = cross_val_score(lin_reg, housing_prepared, housing_labels,
                        scoring="neg_mean_squared_error", cv=10)

# %%
lin_rmse_cv = np.sqrt(-lin_scores)

# %%
lin_rmse_cv.mean()
# Out:
# 69223.18594556303

# %% [markdown]
# ## random forests

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor()
forest_reg.fit(housing_prepared, housing_labels)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### error calculation

# %%
housing_predictions = forest_reg.predict(housing_prepared)

forest_mse = mean_squared_error(housing_labels, housing_predictions)

forest_rmse = np.sqrt(forest_mse)

forest_rmse
# Out:
# 18366.81485927257

# %%
forest_scores = cross_val_score(forest_reg, housing_prepared, housing_labels,
                        scoring="neg_mean_squared_error", cv=10)

forest_rmse_cv = np.sqrt(-forest_scores)

forest_rmse_cv.mean()
# Out:
# 49519.490523267414

# %% [markdown]
# ## exporting the model

# %%
import joblib
joblib.dump(forest_reg, "forest_reg.pkl")
joblib.dump(lin_reg, "lin_reg.pkl")
joblib.dump(tree_reg, "tree_reg.pkl")
# Out:
# ['tree_reg.pkl']

# %%
# joblib.load("tree_reg.pkl")
# Out:
# DecisionTreeRegressor()

# %%
forest_reg.score(housing_prepared, housing_labels)
# Out:
# 0.9747997616566679
