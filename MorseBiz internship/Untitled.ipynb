# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task - 0

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome("/usr/local/bin/chromedriver")
# Out:
# /var/folders/6j/v9zb038n2bxdy2_vbd43mhnc0000gn/T/ipykernel_18016/3393973757.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/usr/local/bin/chromedriver")

# %%
prod_name = []
prod_link = []

driver.get("https://www.magmabrakes.com/catalog/")

# %%
# content = driver.page_source
# soup = BeautifulSoup(content)
# for a in soup.findAll('li',href=True, attrs={'class':'type-product'}):
#     name=a.find('h2', attrs={'class':'woocommerce-loop-product__title'})
#     link=a.find('a', attrs={'class':'button product_type_simple'})

# prod_name.append(name.text)
# prod_link.append(price.text)

# %% [markdown]
# ## Task 1

# %%
import requests
from bs4 import BeautifulSoup
res1 = requests.get('https://www.magmabrakes.com/catalog/')

print("status code - ", res1.status_code, "\n")

soup_data = BeautifulSoup(res1.text, 'html.parser')
# ---------------
# Out:
# status code -  200

# %%
print(soup_data.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script>
# ...

# %%
prod_names = []

for prod in (soup_data.find_all('h2', 'woocommerce-loop-product__title')):
    prod_names.append(prod.string)a

# %%
prod_links = []

for prod in (soup_data.find_all('a', 'product_type_simple')):
    prod_links.append(prod.get('href'))

# %%
prod_links
# Out:
# ['https://www.magmabrakes.com/product/psd976c/',
#  'https://www.magmabrakes.com/product/psd977c/',
#  'https://www.magmabrakes.com/product/psd983c/',
#  'https://www.magmabrakes.com/product/psd987c/',
#  'https://www.magmabrakes.com/product/psd997c/',
#  'https://www.magmabrakes.com/product/psd991m/',
#  'https://www.magmabrakes.com/product/psd974c/',
#  'https://www.magmabrakes.com/product/psd978c/',
#  'https://www.magmabrakes.com/product/psd986c/',
#  'https://www.magmabrakes.com/product/psd989c/',
#  'https://www.magmabrakes.com/product/psd995c/',
#  'https://www.magmabrakes.com/product/psd996c/',
#  'https://www.magmabrakes.com/product/psd998c/',
#  'https://www.magmabrakes.com/product/psd999c/',
#  'https://www.magmabrakes.com/product/psd1118c/',
#  'https://www.magmabrakes.com/product/psd1183c/']

# %%
print(prod_names[0], prod_links[0], sep="  ---  ")
# Out:
# PRO-SERIES Disc Brake Pad Set – FRONT – #PSD976C  ---  https://www.magmabrakes.com/product/psd976c/

# %% [markdown]
# ## Task 2

# %%
res2 = requests.get('https://www.magmabrakes.com/product/psd976c/')
soup_data2 = BeautifulSoup(res2.text, 'html.parser')

# %%
print(soup_data.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script>
# ...

# %%
import pandas as pd

# %%
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

res2 = requests.get('https://www.magmabrakes.com/product/psd976c/', headers=header)

# %%
soup_data2 = BeautifulSoup(res2.text, 'html.parser')

# %% [markdown]
# Sending a post request with the user data ->

# %%
userdata = {'action':'lookup_buyersguide', 'part_key':'009064151'}
resp = requests.post('https://www.magmabrakes.com/wp-admin/admin-ajax.php', data=userdata)

# %%
import json

# %%
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'@attributes': {'ver': '12.0', 'err_num': '0', 'totalrecords': '8'},
#  'partsapps': [{'make': 'LEXUS',
#    'model': 'GX460',
#    'year': '19-10',
#    'engine': 'All',
#    'parttype': 'Disc Brake Pad Set - FRONT',
#    'apptype': 'A',
#    'Qty': '1'},
#   {'make': 'LEXUS',
#    'model': 'GX470',
#    'year': '09-03',
#    'engine': 'All',
#    'parttype': 'Disc Brake Pad Set - FRONT',
#    'apptype': 'A',
#    'Qty': '1'},
#   {'make': 'MITSUBISHI',
#    'model': 'MONTERO',
#    'year': '15-10',
#    'engine': 'All',
#    'parttype': 'Disc Brake Pad Set - FRONT',
#    'apptype': 'A',
#    'Qty': '1'},
#   {'make': 'TOYOTA',
#    'model': '4RUNNER',
#    'year': '19-03',
#    'engine': 'All',
#    'parttype': 'Disc Brake Pad Set - FRONT',
#    'apptype': 'A',
#    'Qty': '1'},
#   {'make': 'TOYOTA',
#    'model': 'FJ CRUISER',
#    'year': '14-07',
#    'engine': 'All',
#    'parttype': 'Disc Brake Pad Set - FRONT',
#    'apptype': 'A',
#    'Qty': '1'},
#   {'make': 'TOYOTA',
# ...
